# %%
from data import Data

# %%
a =  Data()

# %%
a.shape
# Out:
# [4, 1, 4]

# %%
a.add_block(0,0,-3,10)

# %%
# !pip install yfinance

# %%
a.data[:,0,:]
# Out:
# array([[(False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (True, 10, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False)],
#        [(False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False)],
#        [(False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False),
#         (False, 0, 0, 0, 0, False, False), (False, 0, 0, 0, 0, False, False)],
# ...

# %%
# import matplotlib.pyplot as plt  
# import pandas as pd  
# import yfinance as yf  
# # Download historical data for CAC40 index using yfinance  
# data = yf.download('^FTSE:CAC', start='today -12 months', end='today')['Adj Close']

# %%
# data
